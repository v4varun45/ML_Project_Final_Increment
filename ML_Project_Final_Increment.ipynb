# %% [markdown]
# # Petrol Consumption problem

# %% [markdown]
# # 1) Decision Tree Regressor

# %%
pwd
# Out:
# 'C:\\Users\\Pavan_Varun'

# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib .pyplot as plt

# %%
# %matplotlib inline

# %%
# Loading the dataset

Csv_dataset=pd.read_csv("petrol_consumption.csv")

# %%
Csv_dataset.isnull()
# Out:
#     Petrol_tax  Average_income  Paved_Highways  Population_Driver_licence(%)  \
# 0        False           False           False                         False
# 1        False           False           False                         False
# 2        False           False           False                         False
# 3        False           False           False                         False
# 4        False           False           False                         False
# 5        False           False           False                         False
# 6        False           False           False                         False
# 7        False           False           False                         False
# 8        False           False           False                         False
# 9        False           False           False                         False
# 10       False           False           False                         False
# ...

# %%
Csv_dataset.head()
# Out:
#    Petrol_tax  Average_income  Paved_Highways  Population_Driver_licence(%)  \
# 0         9.0            3571            1976                         0.525
# 1         9.0            4092            1250                         0.572
# 2         9.0            3865            1586                         0.580
# 3         7.5            4870            2351                         0.529
# 4         8.0            4399             431                         0.544
#
#    Petrol_Consumption
# 0                 541
# 1                 524
# 2                 561
# 3                 414
# 4                 410

# %%
X = Csv_dataset.drop('Petrol_Consumption', axis=1)
y = Csv_dataset['Petrol_Consumption']

# %%
X.head()
# Out:
#    Petrol_tax  Average_income  Paved_Highways  Population_Driver_licence(%)
# 0         9.0            3571            1976                         0.525
# 1         9.0            4092            1250                         0.572
# 2         9.0            3865            1586                         0.580
# 3         7.5            4870            2351                         0.529
# 4         8.0            4399             431                         0.544

# %%
y.head()
# Out:
# 0    541
# 1    524
# 2    561
# 3    414
# 4    410
# Name: Petrol_Consumption, dtype: int64

# %%
Csv_dataset.describe()
# Out:
#        Petrol_tax  Average_income  Paved_Highways  \
# count   48.000000       48.000000       48.000000
# mean     7.668333     4241.833333     5565.416667
# std      0.950770      573.623768     3491.507166
# min      5.000000     3063.000000      431.000000
# 25%      7.000000     3739.000000     3110.250000
# 50%      7.500000     4298.000000     4735.500000
# 75%      8.125000     4578.750000     7156.000000
# max     10.000000     5342.000000    17782.000000
#
#        Population_Driver_licence(%)  Petrol_Consumption
# count                     48.000000           48.000000
# mean                       0.570333          576.770833
# std                        0.055470          111.885816
# min                        0.451000          344.000000
# 25%                        0.529750          509.500000
# 50%                        0.564500          568.500000
# 75%                        0.595250          632.750000
# max                        0.724000          968.000000

# %%
# Histogram
Csv_dataset.hist()
plt.show()

# %%
# Density plot
Csv_dataset.plot(kind='density',subplots=True,layout=(3,3),sharex=False)
plt.show()

# %%
from sklearn.model_selection import train_test_split
X_train,X_test,y_train,y_test = train_test_split(X,y,test_size=0.50,random_state=0)

# %%
# Training the model

from sklearn.tree import DecisionTreeRegressor
Reg = DecisionTreeRegressor()
Reg.fit(X_train,y_train)
y_pred = Reg.predict(X_test)
y_pred
# Out:
# array([547., 460., 714., 591., 644., 644., 591., 540., 498., 464., 414.,
#        591., 714., 644., 540., 524., 632., 640., 566., 508., 414., 508.,
#        644., 540.])

# %%
# Creating a dataframe

Data_frame = pd.DataFrame({"Actual":y_test, "predicted":y_pred})
Data_frame
# Out:
#     Actual  predicted
# 29     534      547.0
# 4      410      460.0
# 26     577      714.0
# 30     571      591.0
# 32     577      644.0
# 37     704      644.0
# 34     487      591.0
# 40     587      540.0
# 7      467      498.0
# 10     580      464.0
# 11     471      414.0
# 31     554      591.0
# 33     628      714.0
# 27     631      644.0
# 47     524      540.0
# 2      561      524.0
# 46     610      632.0
# 18     865      640.0
# 15     635      566.0
# 28     574      508.0
# 22     464      414.0
# 16     603      508.0
# 41     699      644.0
# 20     649      540.0

# %%
plt.figure(figsize=(8, 10))
ax = sns.distplot(y_test, hist=False, color="r", label="Actual Values")
sns.distplot(y_pred, hist=False, color="g", label="Predicted Values" , ax=ax)

plt.title('Actual vs Predicted Values')
plt.legend(loc="upper right")

plt.show()
plt.close()
# Out:
# C:\Users\Pavan_Varun\anaconda3\lib\site-packages\seaborn\distributions.py:2551: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#   warnings.warn(msg, FutureWarning)
# C:\Users\Pavan_Varun\anaconda3\lib\site-packages\seaborn\distributions.py:2551: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#   warnings.warn(msg, FutureWarning)

# %%
# Finding the Errors

from sklearn import metrics
print('Mean Absolute Error:',metrics.mean_absolute_error(y_test,y_pred))
print('Mean Square Error:',metrics.mean_squared_error(y_test,y_pred))
print('Root Mean Square Error:',np.sqrt(metrics.mean_squared_error(y_test,y_pred)))
# Out:
# Mean Absolute Error: 65.91666666666667
# Mean Square Error: 6576.416666666667
# Root Mean Square Error: 81.09510877153238

# %% [raw]
# ***
# Mean of the Target variable which is Petrol_Consumption is 576.770833
# 10% of Mean = 57.677
#
# Decision Tree Regressor is not a Good Model because it's Root Mean Square Error value is greater than the 10% Mean of the Target variable
#
# ***

# %% [markdown]
# # 2) Random Forest Regressor

# %%
# Loading the dataset

dataset_Forest=pd.read_csv("petrol_consumption.csv")

# %%
dataset_Forest.head()
# Out:
#    Petrol_tax  Average_income  Paved_Highways  Population_Driver_licence(%)  \
# 0         9.0            3571            1976                         0.525
# 1         9.0            4092            1250                         0.572
# 2         9.0            3865            1586                         0.580
# 3         7.5            4870            2351                         0.529
# 4         8.0            4399             431                         0.544
#
#    Petrol_Consumption
# 0                 541
# 1                 524
# 2                 561
# 3                 414
# 4                 410

# %%
X = dataset_Forest.drop('Petrol_Consumption', axis=1)
y = dataset_Forest['Petrol_Consumption']

# %%
X.head()
# Out:
#    Petrol_tax  Average_income  Paved_Highways  Population_Driver_licence(%)
# 0         9.0            3571            1976                         0.525
# 1         9.0            4092            1250                         0.572
# 2         9.0            3865            1586                         0.580
# 3         7.5            4870            2351                         0.529
# 4         8.0            4399             431                         0.544

# %%
y.head()
# Out:
# 0    541
# 1    524
# 2    561
# 3    414
# 4    410
# Name: Petrol_Consumption, dtype: int64

# %%
dataset_Forest.describe()
# Out:
#        Petrol_tax  Average_income  Paved_Highways  \
# count   48.000000       48.000000       48.000000
# mean     7.668333     4241.833333     5565.416667
# std      0.950770      573.623768     3491.507166
# min      5.000000     3063.000000      431.000000
# 25%      7.000000     3739.000000     3110.250000
# 50%      7.500000     4298.000000     4735.500000
# 75%      8.125000     4578.750000     7156.000000
# max     10.000000     5342.000000    17782.000000
#
#        Population_Driver_licence(%)  Petrol_Consumption
# count                     48.000000           48.000000
# mean                       0.570333          576.770833
# std                        0.055470          111.885816
# min                        0.451000          344.000000
# 25%                        0.529750          509.500000
# 50%                        0.564500          568.500000
# 75%                        0.595250          632.750000
# max                        0.724000          968.000000

# %%
from sklearn.model_selection import train_test_split
X_train,X_test,y_train,y_test = train_test_split(X,y,test_size=0.50,random_state=0)

# %%
# Training the model

from sklearn.ensemble import RandomForestRegressor
For_Reg = RandomForestRegressor(n_estimators=50, random_state=0)
For_Reg.fit(X_train,y_train)
y_pred = For_Reg.predict(X_test)
y_pred
# Out:
# array([569.32, 505.46, 621.48, 629.78, 632.42, 608.48, 613.12, 628.4 ,
#        489.14, 518.62, 454.32, 629.78, 632.78, 602.18, 519.26, 561.72,
#        618.58, 798.32, 539.7 , 546.54, 447.6 , 545.28, 643.7 , 709.38])

# %%
# Creating a dataframe

Data_frame01 = pd.DataFrame({"Actual":y_test, "predicted":y_pred})
Data_frame01
# Out:
#     Actual  predicted
# 29     534     569.32
# 4      410     505.46
# 26     577     621.48
# 30     571     629.78
# 32     577     632.42
# 37     704     608.48
# 34     487     613.12
# 40     587     628.40
# 7      467     489.14
# 10     580     518.62
# 11     471     454.32
# 31     554     629.78
# 33     628     632.78
# 27     631     602.18
# 47     524     519.26
# 2      561     561.72
# 46     610     618.58
# 18     865     798.32
# 15     635     539.70
# 28     574     546.54
# 22     464     447.60
# 16     603     545.28
# 41     699     643.70
# 20     649     709.38

# %%
plt.figure(figsize=(8, 10))
ax = sns.distplot(y_test, hist=False, color="r", label="Actual Values")
sns.distplot(y_pred, hist=False, color="g", label="Predicted Values" , ax=ax)

plt.title('Actual vs Predicted Values')
plt.legend(loc="upper right")

plt.show()
plt.close()
# Out:
# C:\Users\Pavan_Varun\anaconda3\lib\site-packages\seaborn\distributions.py:2551: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#   warnings.warn(msg, FutureWarning)
# C:\Users\Pavan_Varun\anaconda3\lib\site-packages\seaborn\distributions.py:2551: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#   warnings.warn(msg, FutureWarning)

# %%
# Finding the Errors

from sklearn import metrics
print('Mean Absolute Error:',metrics.mean_absolute_error(y_test,y_pred))
print('Mean Square Error:',metrics.mean_squared_error(y_test,y_pred))
print('Root Mean Square Error:',np.sqrt(metrics.mean_squared_error(y_test,y_pred)))
# Out:
# Mean Absolute Error: 48.13999999999999
# Mean Square Error: 3392.6936999999984
# Root Mean Square Error: 58.246834248738345

# %% [raw]
# ***
# Mean of the Target variable which is Petrol_Consumption is 576.770833
# 10% of Mean = 57.677
#
# Random Forest Regressor is not a Good Model because it's Root Mean Square Error value is greater than the 10% Mean of the Target variable
#
# ***

# %% [markdown]
# # 3) Linear Regression

# %%
# Loading the dataset

dataset_linear=pd.read_csv("petrol_consumption.csv")

# %%
dataset_linear.head()
# Out:
#    Petrol_tax  Average_income  Paved_Highways  Population_Driver_licence(%)  \
# 0         9.0            3571            1976                         0.525
# 1         9.0            4092            1250                         0.572
# 2         9.0            3865            1586                         0.580
# 3         7.5            4870            2351                         0.529
# 4         8.0            4399             431                         0.544
#
#    Petrol_Consumption
# 0                 541
# 1                 524
# 2                 561
# 3                 414
# 4                 410

# %%
X = dataset_linear.drop('Petrol_Consumption', axis=1)
y = dataset_linear['Petrol_Consumption']

# %%
X.head()
# Out:
#    Petrol_tax  Average_income  Paved_Highways  Population_Driver_licence(%)
# 0         9.0            3571            1976                         0.525
# 1         9.0            4092            1250                         0.572
# 2         9.0            3865            1586                         0.580
# 3         7.5            4870            2351                         0.529
# 4         8.0            4399             431                         0.544

# %%
y.head()
# Out:
# 0    541
# 1    524
# 2    561
# 3    414
# 4    410
# Name: Petrol_Consumption, dtype: int64

# %%
dataset_linear.describe()
# Out:
#        Petrol_tax  Average_income  Paved_Highways  \
# count   48.000000       48.000000       48.000000
# mean     7.668333     4241.833333     5565.416667
# std      0.950770      573.623768     3491.507166
# min      5.000000     3063.000000      431.000000
# 25%      7.000000     3739.000000     3110.250000
# 50%      7.500000     4298.000000     4735.500000
# 75%      8.125000     4578.750000     7156.000000
# max     10.000000     5342.000000    17782.000000
#
#        Population_Driver_licence(%)  Petrol_Consumption
# count                     48.000000           48.000000
# mean                       0.570333          576.770833
# std                        0.055470          111.885816
# min                        0.451000          344.000000
# 25%                        0.529750          509.500000
# 50%                        0.564500          568.500000
# 75%                        0.595250          632.750000
# max                        0.724000          968.000000

# %%
from sklearn.model_selection import train_test_split
X_train,X_test,y_train,y_test = train_test_split(X,y,test_size=0.50,random_state=0)

# %%
# Training the model

from sklearn.linear_model import LinearRegression
lin_Reg = LinearRegression()
lin_Reg.fit(X_train,y_train)
y_pred = lin_Reg.predict(X_test)
y_pred
# Out:
# array([468.44694913, 550.47577274, 589.92253272, 572.15162834,
#        648.44261053, 645.44100327, 517.91331201, 669.80223518,
#        499.66822558, 496.65665888, 406.34708925, 589.35626081,
#        625.69491605, 600.1156384 , 554.21202568, 582.5754118 ,
#        680.35990336, 769.36948011, 589.74139813, 553.40907464,
#        414.93746154, 591.5837364 , 648.46761485, 686.48399684])

# %%
# Creating a dataframe

Data_frame02 = pd.DataFrame({"Actual":y_test, "predicted":y_pred})
Data_frame02
# Out:
#     Actual   predicted
# 29     534  468.446949
# 4      410  550.475773
# 26     577  589.922533
# 30     571  572.151628
# 32     577  648.442611
# 37     704  645.441003
# 34     487  517.913312
# 40     587  669.802235
# 7      467  499.668226
# 10     580  496.656659
# 11     471  406.347089
# 31     554  589.356261
# 33     628  625.694916
# 27     631  600.115638
# 47     524  554.212026
# 2      561  582.575412
# 46     610  680.359903
# 18     865  769.369480
# 15     635  589.741398
# 28     574  553.409075
# 22     464  414.937462
# 16     603  591.583736
# 41     699  648.467615
# 20     649  686.483997

# %%
plt.figure(figsize=(8, 10))
ax = sns.distplot(y_test, hist=False, color="r", label="Actual Values")
sns.distplot(y_pred, hist=False, color="g", label="Predicted Values" , ax=ax)

plt.title('Actual vs Predicted Values')
plt.legend(loc="upper right")

plt.show()
plt.close()
# Out:
# C:\Users\Pavan_Varun\anaconda3\lib\site-packages\seaborn\distributions.py:2551: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#   warnings.warn(msg, FutureWarning)
# C:\Users\Pavan_Varun\anaconda3\lib\site-packages\seaborn\distributions.py:2551: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#   warnings.warn(msg, FutureWarning)

# %%
# Finding the Errors

from sklearn import metrics
print('Mean Absolute Error:',metrics.mean_absolute_error(y_test,y_pred))
print('Mean Square Error:',metrics.mean_squared_error(y_test,y_pred))
print('Root Mean Square Error:',np.sqrt(metrics.mean_squared_error(y_test,y_pred)))
# Out:
# Mean Absolute Error: 47.71470395631436
# Mean Square Error: 3307.8706639672764
# Root Mean Square Error: 57.514091003573

# %% [raw]
# ***
# Mean of the Target variable which is Petrol_Consumption is 576.770833
# 10% of Mean = 57.677
#
# Linear Regresion is a very Good Model because it's Root Mean Square Error value is less than the 10% Mean of the Target variable.
#
# ***

# %% [markdown]
# # 4)Naive bayes

# %%
Naive=pd.read_csv('petrol_consumption.csv')

# %%
Naive.head()
# Out:
#    Petrol_tax  Average_income  Paved_Highways  Population_Driver_licence(%)  \
# 0         9.0            3571            1976                         0.525
# 1         9.0            4092            1250                         0.572
# 2         9.0            3865            1586                         0.580
# 3         7.5            4870            2351                         0.529
# 4         8.0            4399             431                         0.544
#
#    Petrol_Consumption
# 0                 541
# 1                 524
# 2                 561
# 3                 414
# 4                 410

# %%
X = Naive.drop('Petrol_Consumption', axis=1)
y = Naive['Petrol_Consumption']

# %%
X.head()
# Out:
#    Petrol_tax  Average_income  Paved_Highways  Population_Driver_licence(%)
# 0         9.0            3571            1976                         0.525
# 1         9.0            4092            1250                         0.572
# 2         9.0            3865            1586                         0.580
# 3         7.5            4870            2351                         0.529
# 4         8.0            4399             431                         0.544

# %%
y.head()
# Out:
# 0    541
# 1    524
# 2    561
# 3    414
# 4    410
# Name: Petrol_Consumption, dtype: int64

# %%
Naive.describe()
# Out:
#        Petrol_tax  Average_income  Paved_Highways  \
# count   48.000000       48.000000       48.000000
# mean     7.668333     4241.833333     5565.416667
# std      0.950770      573.623768     3491.507166
# min      5.000000     3063.000000      431.000000
# 25%      7.000000     3739.000000     3110.250000
# 50%      7.500000     4298.000000     4735.500000
# 75%      8.125000     4578.750000     7156.000000
# max     10.000000     5342.000000    17782.000000
#
#        Population_Driver_licence(%)  Petrol_Consumption
# count                     48.000000           48.000000
# mean                       0.570333          576.770833
# std                        0.055470          111.885816
# min                        0.451000          344.000000
# 25%                        0.529750          509.500000
# 50%                        0.564500          568.500000
# 75%                        0.595250          632.750000
# max                        0.724000          968.000000

# %%
from sklearn.model_selection import train_test_split
X_train,X_test,y_train,y_test = train_test_split(X,y,test_size=0.4,random_state=0)

# %%
# Training the model
from sklearn.naive_bayes import*
clf=BernoulliNB()
clf.fit(X_train,y_train)
y_pred = clf.predict(X_test)
y_pred
# Out:
# array([464, 464, 464, 464, 464, 464, 464, 464, 464, 464, 464, 464, 464,
#        464, 464, 464, 464, 464, 464, 464], dtype=int64)

# %%
# Creating a dataframe

Data_frame03 = pd.DataFrame({"Actual":y_test, "predicted":y_pred})
Data_frame03
# Out:
#     Actual  predicted
# 29     534        464
# 4      410        464
# 26     577        464
# 30     571        464
# 32     577        464
# 37     704        464
# 34     487        464
# 40     587        464
# 7      467        464
# 10     580        464
# 11     471        464
# 31     554        464
# 33     628        464
# 27     631        464
# 47     524        464
# 2      561        464
# 46     610        464
# 18     865        464
# 15     635        464
# 28     574        464

# %%
from sklearn.metrics import accuracy_score

accuracy_score(y_test,y_pred,normalize=True)
# Out:
# 0.0

# %%
plt.figure(figsize=(8, 10))
ax = sns.distplot(y_test, hist=False, color="r", label="Actual Values")
sns.distplot(y_pred, hist=False, color="g", label="Predicted Values" , ax=ax)

plt.title('Actual vs Predicted Values')
plt.legend(loc="upper right")

plt.show()
plt.close()
# Out:
# C:\Users\Pavan_Varun\anaconda3\lib\site-packages\seaborn\distributions.py:2551: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#   warnings.warn(msg, FutureWarning)
# C:\Users\Pavan_Varun\anaconda3\lib\site-packages\seaborn\distributions.py:2551: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#   warnings.warn(msg, FutureWarning)
# C:\Users\Pavan_Varun\anaconda3\lib\site-packages\seaborn\distributions.py:305: UserWarning: Dataset has 0 variance; skipping density estimate.
#   warnings.warn(msg, UserWarning)

# %% [raw]
# ***
# Mean of the Target variable which is Petrol_Consumption is 576.770833
# 10% of Mean = 57.677
#
# Naive bayes is a very bad Model because it's not at all predicting. It's accuracy score is zero
#
# ***
